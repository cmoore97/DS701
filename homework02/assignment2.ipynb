# %%
# Initialize Otter
import otter
grader = otter.Notebook("assignment2.ipynb")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Probability, Statistics and Distances Homework
#
# Please complete the following assignment. Run all cells and submit your completed notebook through Gradescope.
#
# This assignment covers the following topics:
#
# - Frequentist vs Bayesian probability
# - Definition of probability
# - Conditional probability and Bayes theorem
# - Random variables
# - Expectation, variance, and covariance
# - Binomial distribution
# - Poisson distribution
# - Gaussian distribution
# - Jaccard Index
# - Euclidean Distances

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# #### 1. Which of the following statements best describes the Bayesian interpretation of probability?
#
#     A) Probability is the long-run relative frequency of an event occurring in repeated trials.
#     B) Probability represents a degree of belief or confidence in the occurrence of an event.
#     C) Probability is the ratio of favorable outcomes to the total number of equally likely outcomes.
#     D) Probability is the measure of the likelihood that a random variable takes a specific value.

# %% [markdown]
# B

# %% [markdown]
# <!-- END QUESTION -->
#
# #### 2. Write a function `time_to_six() -> tuple` that simulates rolling a fair six-sided die repeatedly until a `6` appears.
# The function should return a tuple `(rolls, count)`

# %%
import numpy as np

def time_to_six() -> tuple:
    rolls = []
    done = False

    while not done:
        roll = np.random.randint(1, 7) 
        rolls.append(roll)

        if roll == 6:
            done = True

    return rolls, len(rolls)

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!

# %% [markdown]
# #### Question 3.
#
# Suppose that 0.5% of all credit card transactions are fraudulent. A fraud detection system correctly flags fraudulent transactions 96% of the time (sensitivity), and incorrectly flags legitimate transactions 3% of the time (false positive rate). If a randomly selected transaction is flagged, what is the probability that it is actually fraudulent?
#
#     Return your answer as a float between 0 and 1.

# %%
def answer3():
    P_F = 0.005         
    P_not_F = 0.995     
    P_Flag_given_F = 0.96      
    P_Flag_given_not_F = 0.03  

    FP = .03
    TN = .005 * .96
    return 1 - (FP / (FP + TN))

# %%
grader.check("q3")
# Out:
# q3 results: All test cases passed!

# %% [markdown]
# #### Question 4.
#
# Let X be a discrete random variable that takes the values 1, 3, 5 with probabilities P(X=1)=0.4, P(X=3)=0.2, P(X=5)=0.4.
#
# - Compute the expected value E[X].
# - Return your answer as a float.

# %%
def ans4():
    return (1 * .4) + (3 * .2) + (5 * .4)

# %%
grader.check("q4")
# Out:
# q4 results: All test cases passed!

# %% [markdown]
# ####  Question 5.
#
# Let X be a random variable as in Question 4. Compute the variance Var(X).
# -    Return your answer as a float.

# %%
import math
def ans5():
    E_X = ans4()   
    return .4 * math.pow((1 - E_X), 2) + .2 * math.pow((3 - E_X), 2) + .4 * math.pow((5 - E_X), 2)

# %%
ans5()
# Out:
# 3.2

# %%
grader.check("q5")
# Out:
# q5 results: All test cases passed!

# %% [markdown]
# #### Question 6.
#
# A fair coin is tossed 10 times. What is the probability of getting exactly 6 heads?
#
#     Return your answer as a float.

# %%
import math
from math import comb
def ans6():
    return (comb(10, 6) / math.pow(2, 10))

# %%
ans6()
# Out:
# 0.205078125

# %%
grader.check("q6")
# Out:
# q6 results: All test cases passed!

# %% [markdown]
# #### Question 7.
#
# A radioactive source emits particles following a Poisson distribution with an average rate of λ = 4 particles per minute.
#
#     What is the probability that exactly 6 particles are emitted in a given minute?
#
#     Return your answer as a float.

# %%
from scipy.stats import poisson
def ans7():
    λ = 4
    k = 6
    return 1 - poisson.cdf(k, λ)

# %%
grader.check("q7")
# Out:
# q7 results: All test cases passed!

# %% [markdown]
# #### Question 8.
#
# Assuming that the heights of adult males are normally distributed with a mean of 70 inches and a standard deviation of 3 inches, what is the probability that a randomly selected male is taller than 75 inches?
#
#     Return your answer as a float.

# %%
from scipy.stats import norm
def ans8():
    mu = 70
    sigma = 3
    x = 75
    dist = norm(mu, sigma)

    return 1 - dist.cdf(x)

ans8()
# Out:
# np.float64(0.047790352272814696)

# %%
grader.check("q8")
# Out:
# q8 results: All test cases passed!

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(run_tests=True)
# Out:
# C:\Users\Cameron\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\check\notebook.py:494: UserWarning: Could not locate a PDF to include
#   warnings.warn("Could not locate a PDF to include")
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Save your notebook first, then run this cell to export your submission.
# ----> 2 grader.export(run_tests=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\check\utils.py:206, in grading_mode_disabled(wrapped, self, args, kwargs)
#     204 if type(self)._grading_mode:
#     205     return
# --> 206 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\check\utils.py:188, in incompatible_with.<locals>.incompatible(wrapped, self, args, kwargs)
#     186     else:
#     187         return
# --> 188 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\check\utils.py:242, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     240 except Exception as e:
#     241     self._log_event(event_type, success=False, error=e)
# --> 242     raise e
#     244 if ret is None:
#     245     ret = LoggedEventReturnValue(None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\check\utils.py:238, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     233 """
#     234 Runs a method, catching any errors and logging the call. Returns the unwrapped return value
#     235 of the wrapped function.
#     236 """
#     237 try:
# --> 238     ret: Optional[LoggedEventReturnValue[T]] = wrapped(*args, **kwargs)
#     240 except Exception as e:
#     241     self._log_event(event_type, success=False, error=e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\check\notebook.py:551, in Notebook.export(self, nb_path, export_path, pdf, filtering, pagebreaks, files, display_link, force_save, run_tests, ignore_log)
#     549 if pdf_created or not self._nbmeta_config.require_no_pdf_confirmation:
#     550     if pdf_error is not None:
# --> 551         raise pdf_error
#     552     continue_export()
#     553 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\check\notebook.py:485, in Notebook.export(self, nb_path, export_path, pdf, filtering, pagebreaks, files, display_link, force_save, run_tests, ignore_log)
#     483 if pdf:
#     484     try:
# --> 485         pdf_path = export_notebook(nb_path, filtering=filtering, pagebreaks=pagebreaks)
#     486     except Exception as e:
#     487         pdf_error = e
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\export\__init__.py:43, in export_notebook(nb_path, dest, exporter_type, **kwargs)
#      40     pdf_name = os.path.splitext(nb_path)[0] + ".pdf"
#      42 Exporter = get_exporter(exporter_type=exporter_type)
# ---> 43 Exporter.convert_notebook(nb_path, pdf_name, **kwargs)
#      45 return pdf_name
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\export\exporters\via_latex.py:52, in PDFViaLatexExporter.convert_notebook(cls, nb_path, dest, xecjk, **kwargs)
#      49 if xecjk:
#      50     options["template"] = "via_latex_xecjk"
# ---> 52 nb = cls.load_notebook(
#      53     nb_path, filtering=options["filtering"], pagebreaks=options["pagebreaks"]
#      54 )
#      56 nbconvert.TemplateExporter.extra_template_basedirs = [str(TEMPLATE_DIR)]
#      57 orig_template_name = nbconvert.TemplateExporter.template_name
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\otter\export\exporters\base_exporter.py:72, in BaseExporter.load_notebook(cls, nb_path, filtering, pagebreaks)
#      58 """
#      59 Loads notebook at ``nb_path`` with nbformat and returns the parsed notebookly filtered
#      60 and with pagebreak metadata hidden in HTML comments.
#    (...)     69     ``nbformat.NotebookNode``: the parsed and (optionally) filtered notebook
#      70 """
#      71 with open(nb_path) as f:
# ---> 72     notebook = nbformat.read(f, as_version=NBFORMAT_VERSION)
#      73 if filtering:
#      74     notebook = cls.filter_cells(notebook, pagebreaks=pagebreaks)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nbformat\__init__.py:169, in read(fp, as_version, capture_validation_error, **kwargs)
#     141 """Read a notebook from a file as a NotebookNode of the given version.
#     142
#     143 The string can contain a notebook of any version.
#    (...)    165     The notebook that was read.
#     166 """
#     168 try:
# --> 169     buf = fp.read()
#     170 except AttributeError:
#     171     with open(fp, encoding="utf8") as f:  # noqa: PTH123
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2032.0_x64__qbz5n2kfra8p0\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x8d in position 5993: character maps to <undefined>
